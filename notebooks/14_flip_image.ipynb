# %%
import cv2
import matplotlib.pyplot as plt

# %%
depth_img_path = "../notebooks/woodblock_depth_xyz/whole_02801_mk30_xyz.png"

# %%
print_img_path = "../notebooks/scan_imgs/02801_mk30.jpg"

# %%
depth_img = cv2.imread(depth_img_path)
print_img = cv2.imread(print_img_path)

# %%
flip_depth_img = cv2.flip(depth_img, 1)

# %%
plt.figure(figsize=(12, 9))
plt.imshow(depth_img)

# %%
plt.figure(figsize=(12, 9))
plt.imshow(print_img)

# %%
plt.figure(figsize=(12, 9))
plt.imshow(flip_depth_img);

# %%
cv2.imwrite("../notebooks/woodblock_depth_xyz/whole_02801_mk30_xyz.png", flip_depth_img)
# Out:
# True
